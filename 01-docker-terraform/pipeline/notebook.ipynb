# %%
import pandas as pd

# %%
url = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz'

# %%
dtype = {
    "VendorID": "Int64",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "congestion_surcharge": "float64"
}
parse_dates = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg://root:root@localhost:5432/ny_taxi')

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
df_iter = pd.read_csv(
    url,
    dtype=dtype,
    parse_dates=parse_dates,
    iterator=True,
    chunksize=100000
)

# %%
df_iter

# %%
from tqdm.auto import tqdm

# %%
for df_chunk in tqdm(df_iter):
    df_chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# 0it [00:00, ?it/s]
# error ignored terminating <psycopg.Pipeline [BAD] at 0x79c811366350>: consuming input failed: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[33], line 2
#       1 for df_chunk in tqdm(df_iter):
# ----> 2     df_chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/pandas/core/generic.py:3052, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3048         3
#    3049         """  # noqa: E501
#    3050         from pandas.io import sql
#    3051
# -> 3052         return sql.to_sql(
#    3053             self,
#    3054             name,
#    3055             con,
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/pandas/io/sql.py:840, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     835 elif not isinstance(frame, DataFrame):
#     836     raise NotImplementedError(
#     837         "'frame' argument should be either a Series or a DataFrame"
#     838     )
# --> 840 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     841     return pandas_sql.to_sql(
#     842         frame,
#     843         name,
#    (...)    852         **engine_kwargs,
#     853     )
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/pandas/io/sql.py:1658, in SQLDatabase.__exit__(self, *args)
#    1656 def __exit__(self, *args) -> None:
#    1657     if not self.returns_generator:
# -> 1658         self.exit_stack.close()
#
# File ~/.local/share/uv/python/cpython-3.13.12-linux-x86_64-gnu/lib/python3.13/contextlib.py:627, in ExitStack.close(self)
#     625 def close(self):
#     626     """Immediately unwind the context stack."""
# --> 627     self.__exit__(None, None, None)
#
# File ~/.local/share/uv/python/cpython-3.13.12-linux-x86_64-gnu/lib/python3.13/contextlib.py:619, in ExitStack.__exit__(self, *exc_details)
#     615 try:
#     616     # bare "raise exc" replaces our carefully
#     617     # set-up context
#     618     fixed_ctx = exc.__context__
# --> 619     raise exc
#     620 except BaseException:
#     621     exc.__context__ = fixed_ctx
#
# File ~/.local/share/uv/python/cpython-3.13.12-linux-x86_64-gnu/lib/python3.13/contextlib.py:604, in ExitStack.__exit__(self, *exc_details)
#     602 else:
#     603     exc_details = type(exc), exc, exc.__traceback__
# --> 604 if cb(*exc_details):
#     605     suppressed_exc = True
#     606     pending_raise = False
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/util.py:147, in TransactionalContext.__exit__(self, type_, value, traceback)
#     145     self.commit()
#     146 except:
# --> 147     with util.safe_reraise():
#     148         if self._rollback_can_be_called():
#     149             self.rollback()
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/util.py:145, in TransactionalContext.__exit__(self, type_, value, traceback)
#     143 if type_ is None and self._transaction_is_active():
#     144     try:
# --> 145         self.commit()
#     146     except:
#     147         with util.safe_reraise():
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2640, in Transaction.commit(self)
#    2624 """Commit this :class:`.Transaction`.
#    2625
#    2626 The implementation of this may vary based on the type of transaction in
#    (...)   2637
#    2638 """
#    2639 try:
# -> 2640     self._do_commit()
#    2641 finally:
#    2642     assert not self.is_active
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2745, in RootTransaction._do_commit(self)
#    2742 assert self.connection._transaction is self
#    2744 try:
# -> 2745     self._connection_commit_impl()
#    2746 finally:
#    2747     # whether or not commit succeeds, cancel any
#    2748     # nested transactions, make this transaction "inactive"
#    2749     # and remove it as a reset agent
#    2750     if self.connection._nested_transaction:
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2716, in RootTransaction._connection_commit_impl(self)
#    2715 def _connection_commit_impl(self) -> None:
# -> 2716     self.connection._commit_impl()
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1147, in Connection._commit_impl(self)
#    1145     self.engine.dialect.do_commit(self.connection)
#    1146 except BaseException as e:
# -> 1147     self._handle_dbapi_exception(e, None, None, None, None)
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2366, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2364     else:
#    2365         assert exc_info[1] is not None
# -> 2366         raise exc_info[1].with_traceback(exc_info[2])
#    2367 finally:
#    2368     del self._reentrant_error
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1145, in Connection._commit_impl(self)
#    1143         self._log_info("COMMIT")
#    1144 try:
# -> 1145     self.engine.dialect.do_commit(self.connection)
#    1146 except BaseException as e:
#    1147     self._handle_dbapi_exception(e, None, None, None, None)
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:581, in Connection.connection(self)
#     579 if self._dbapi_connection is None:
#     580     try:
# --> 581         return self._revalidate_connection()
#     582     except (exc.PendingRollbackError, exc.ResourceClosedError):
#     583         raise
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:673, in Connection._revalidate_connection(self)
#     671 if self.__can_reconnect and self.invalidated:
#     672     if self._transaction is not None:
# --> 673         self._invalid_transaction()
#     674     self._dbapi_connection = self.engine.raw_connection()
#     675     return self._dbapi_connection
#
# File /workspaces/data_engineering_zoomcamp_docker_workshop/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:663, in Connection._invalid_transaction(self)
#     662 def _invalid_transaction(self) -> NoReturn:
# --> 663     raise exc.PendingRollbackError(
#     664         "Can't reconnect until invalid %stransaction is rolled "
#     665         "back.  Please rollback() fully before proceeding"
#     666         % ("savepoint " if self._nested_transaction is not None else ""),
#     667         code="8s2b",
#     668     )
#
# PendingRollbackError: Can't reconnect until invalid transaction is rolled back.  Please rollback() fully before proceeding (Background on this error at: https://sqlalche.me/e/20/8s2b)
